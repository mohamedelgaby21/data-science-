# %% [markdown]
# # Phase 5: Evaluation
#
# **CRISP-DM Phase Description:**
# At this stage, the model(s) appear to have high quality from a technical standpoint. Before proceeding to final deployment, it is important to evaluate the model more thoroughly and review the steps that were executed to construct it, to be certain the model properly achieves the business objectives. A key objective is to determine if there is some important business issue that has not been sufficiently considered.
#
# ---

# %%
# Standard imports
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ### Task 1: Evaluate Results
#
# Assess how well the model(s) meet the **business success criteria** originally defined in **Phase 1 (Business Understanding)**. This is distinct from the technical assessment in Phase 4 — here you ask: *"Does this model actually solve the business problem?"*
#
# Key activities:
# - **Map Technical Metrics to Business Criteria:** Compare the model's performance metrics (from Phase 4) against the business success criteria and data mining success criteria defined in Phase 1.
# - **Business Impact Assessment:** Translate technical performance into business-relevant terms (e.g., "The model's 92% recall means we would catch 92 out of every 100 fraudulent transactions").
# - **Gap Analysis:** Identify any gaps between expected and actual performance.
# - **Approved Models:** List the model(s) that pass the evaluation and the ones that do not.
#
# **Instructions:** Reference the `business_objectives` and `data_mining_goals` dictionaries from Phase 1. Compare each success criterion against the model's actual performance.

# %%
evaluation = {
    "business_criteria": [
        {
            "criterion": "Identify at-risk students for early intervention",
            "target": "Capture > 60% of students who actually fail (Recall)",
            "achieved": "65.2% Recall for At-Risk class",
            "met": True
        },
        {
            "criterion": "Improve accuracy of student performance predictions",
            "target": "Accuracy > 65%",
            "achieved": "70.24%",
            "met": True
        }
    ],
    "technical_criteria": [
        {
            "metric": "Model Generalization",
            "target": "Overfitting Gap < 5%",
            "achieved": "2.61%", 
            "met": True
        },
        {
            "metric": "Stable Performance",
            "target": "Cross-Validation Mean > 60%",
            "achieved": "60.09%",
            "met": True
        }
    ],
    "overall_assessment": "The Random Forest model meets all predefined business and technical success criteria.",
    "approved_models": ["Random Forest"],
    "rejected_models": ["Decision Tree (High Overfitting)"]
}

# %%
print("-" * 60)
print("EVALUATION AGAINST BUSINESS SUCCESS CRITERIA")
print("-" * 60)

print("\n--- Business Criteria ---")
for c in evaluation['business_criteria']:
    status = 'PASS' if c['met'] else 'FAIL'
    print(f"[{status}] {c['criterion']}")
    print(f"         Target: {c['target']} | Achieved: {c['achieved']}")

print("\n--- Technical Criteria ---")
for c in evaluation['technical_criteria']:
    status = 'PASS' if c['met'] else 'FAIL'
    print(f"[{status}] {c['metric']}: Target {c['target']} | Achieved: {c['achieved']}")

print(f"\nOverall: {evaluation['overall_assessment']}")
print(f"Approved models: {evaluation['approved_models']}")
print(f"Rejected models: {evaluation['rejected_models']}")
# Out:
# ------------------------------------------------------------
# EVALUATION AGAINST BUSINESS SUCCESS CRITERIA
# ------------------------------------------------------------
#
# --- Business Criteria ---
# [PASS] Identify at-risk students early (First 4 weeks)
#          Target: Actionable early warning system | Achieved: Successfully predicted dropouts using ONLY the first 28 days of clickstream data.
# [PASS] Provide an interpretable model for university staff
#          Target: Clear relationship between engagement and risk | Achieved: Logistic Regression provides clear rules (low early clicks = high risk) unlike complex black-box models.
#
# --- Technical Criteria ---
# [PASS] Overall Accuracy: Target >= 70.0% | Achieved: 71.41%
#
# Overall: The Logistic Regression model successfully meets the business objective. It provides an early, accurate, and highly interpretable warning system for the university to intervene before students drop out.
# Approved models: ['Logistic Regression']
# Rejected models: ['Random Forest (slightly lower accuracy and less interpretable)']

# %%
import pandas as pd

comparison_df = pd.DataFrame({
    "Model": ["Logistic Regression", "Decision Tree", "Random Forest", "XGBoost"],
    "Training Accuracy": ["68.08%", "98.42%", "72.85%", "75.78%"],
    "Testing Accuracy": ["68.54%", "61.90%", "70.24%", "69.69%"],
    "Overfitting Gap": ["-0.46%", "36.52%", "2.61%", "6.10%"]
})

print("=== Final Model Comparison ===")
display(comparison_df)
# Out:
# === Final Model Comparison ===
#                  Model Training Accuracy Testing Accuracy Overfitting Gap
# 0  Logistic Regression            68.08%           68.54%          -0.46%
# 1        Decision Tree            98.42%           61.90%          36.52%
# 2        Random Forest            72.85%           70.24%           2.61%
# 3              XGBoost            75.78%           69.69%           6.10%

# %%
print("=== Evaluation Insight ===")
print("- Random Forest achieved the highest testing accuracy (70.24%) with a relatively small overfitting gap (2.61%).")
print("- XGBoost came second with 69.69% accuracy.")
print("- Logistic Regression showed stable but lower performance at 68.54%.")
print("- Decision Tree had the weakest performance and the highest overfitting gap.")
print("- Therefore, Random Forest was selected as the final deployment model.")
# Out:
# === Evaluation Insight ===
# - Random Forest achieved the highest testing accuracy (70.24%) with a relatively small overfitting gap (2.61%).
# - XGBoost came second with 69.69% accuracy.
# - Logistic Regression showed stable but lower performance at 68.54%.
# - Decision Tree had the weakest performance and the highest overfitting gap.
# - Therefore, Random Forest was selected as the final deployment model.

# %% [markdown]
# ---
# ### Task 2: Review Process
#
# Conduct a thorough review of the entire CRISP-DM process executed so far. The goal is to ensure quality assurance — that no important task or factor was overlooked. Consider:
#
# - **Completeness Check:** Were all relevant data sources considered? Were the data preparation steps sufficient?
# - **Methodology Review:** Were appropriate techniques used at each stage? Were there alternatives worth exploring?
# - **Data Leakage Check:** Did any information from the test set leak into the training process?
# - **Bias and Fairness:** Could the model introduce or amplify any biases? Is the model fair across different subgroups?
# - **Reproducibility:** Can the entire pipeline be reproduced from scratch with consistent results?
#
# **Instructions:** Complete the process review checklist below and document any concerns.

# %%
process_review = {
    "checklist": [
        {"item": "All relevant OULAD data (VLE, demographics) was considered", "status": "Yes", "notes": "Integrated Web Scraping data for GDP as well."},
        {"item": "Data preparation was thorough and documented", "status": "Yes", "notes": "Handled missing values and One-Hot Encoding correctly."},
        {"item": "No data leakage between train and test sets", "status": "Yes", "notes": "Used stratified 80/20 split before any feature scaling."},
        {"item": "Multiple modelling techniques were compared", "status": "Yes", "notes": "Compared LR, DT, RF, and XGBoost."},
        {"item": "Overfitting was actively monitored and addressed", "status": "Yes", "notes": "Caught DT overfitting and prioritized Random Forest for stability."},
        {"item": "Results are reproducible (random seeds set)", "status": "Yes", "notes": "Fixed random_state=42 across all steps."}
    ],
    "overall_quality": "High. The process followed the CRISP-DM methodology rigorously.",
    "areas_for_improvement": ["Try more complex Feature Engineering for VLE activity", "Test more Hyperparameter combinations for XGBoost"]
}

# %%
# 2. Display the process review beautifully
print("=== 📋 Process Review Checklist ===")
for item in process_review['checklist']:
    print(f"[{item['status']:^7}] {item['item']}")
    if item['notes']:
        print(f"          Note: {item['notes']}")

print(f"\n🌟 Overall Quality: {process_review['overall_quality']}")

if process_review['areas_for_improvement']:
    print("\n📈 Areas for Improvement:")
    for area in process_review['areas_for_improvement']:
        print(f"  - {area}")
# Out:
# === 📋 Process Review Checklist ===
# [  Yes  ] All relevant OULAD data (VLE, demographics) was considered
#           Note: Integrated Web Scraping data for GDP as well.
# [  Yes  ] Data preparation was thorough and documented
#           Note: Handled missing values and One-Hot Encoding correctly.
# [  Yes  ] No data leakage between train and test sets
#           Note: Used stratified 80/20 split before any feature scaling.
# [  Yes  ] Multiple modelling techniques were compared
#           Note: Compared LR, DT, RF, and XGBoost.
# [  Yes  ] Overfitting was actively monitored and addressed
#           Note: Caught DT overfitting and prioritized Random Forest for stability.
# [  Yes  ] Results are reproducible (random seeds set)
#           Note: Fixed random_state=42 across all steps.
#
# 🌟 Overall Quality: High. The process followed the CRISP-DM methodology rigorously.
#
# 📈 Areas for Improvement:
#   - Try more complex Feature Engineering for VLE activity
#   - Test more Hyperparameter combinations for XGBoost

# %% [markdown]
# ---
# ### Task 3: Determine Next Steps
#
# Based on the evaluation results and process review, decide on the next course of action. The three main options are:
#
# 1. **Proceed to Deployment:** The model meets all criteria and is ready for deployment.
# 2. **Iterate:** Go back to a previous phase (e.g., Data Preparation or Modelling) to improve the model before deployment.
# 3. **Terminate:** The project is not viable in its current form and should be re-scoped or abandoned.
#
# **Instructions:** Document your decision and provide a clear rationale.

# %%
next_steps = {
    "decision": "Proceed to Deployment",
    "rationale": "The Random Forest model is stable, reliable, and meets the business goals for student risk identification.",
    "if_deploying": {
        "selected_model": "Random Forest Classifier",
        "deployment_priority": "High"
    }
}

# %%
# 2. Display the decision 
print("=" * 60)
print("NEXT STEPS DECISION")
print("=" * 60)
print(f"\nDecision : {next_steps['decision']}")
print(f"Rationale: {next_steps['rationale']}")

if next_steps['decision'] == 'Iterate':
    print(f"\nReturn to: {next_steps['if_iterating']['return_to_phase']}")
    for action in next_steps['if_iterating']['specific_actions']:
        print(f"  - {action}")
elif next_steps['decision'] == 'Proceed to Deployment':
    print(f"\nModel to deploy: {next_steps['if_deploying']['selected_model']}")
    print(f"Priority: {next_steps['if_deploying']['deployment_priority']}")
# Out:
# ============================================================
# NEXT STEPS DECISION
# ============================================================
#
# Decision : Proceed to Deployment
# Rationale: The Random Forest model is stable, reliable, and meets the business goals for student risk identification.
#
# Model to deploy: Random Forest Classifier
# Priority: High

# %%
print("=== Final Evaluation Decision ===")
print("Random Forest was selected as the final approved model for deployment.")
print("The model showed the best overall performance and is ready for use in Phase 6.")
# Out:
# === Final Evaluation Decision ===
# Random Forest was selected as the final approved model for deployment.
# The model showed the best overall performance and is ready for use in Phase 6.
