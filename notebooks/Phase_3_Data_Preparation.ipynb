# %% [markdown]
# # Phase 3: Data Preparation
#
# **CRISP-DM Phase Description:**
# This phase covers all activities to construct the final dataset from the initial raw data. Data preparation tasks are likely to be performed multiple times, and not in any prescribed order. This is typically the longest and most time-consuming phase of the CRISP-DM lifecycle.
#
# ---

# %%
# Standard library imports for this phase
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
# %matplotlib inline

# %%
## Define the path to your data folder
DATA_DIR = '../data/'

# Load our three datasets
print("Loading datasets...")
student_info = pd.read_csv(f"{DATA_DIR}studentInfo.csv")
vle_mapping = pd.read_csv(f"{DATA_DIR}vle.csv")
student_vle = pd.read_csv(f"{DATA_DIR}studentVle.csv")
print("✅ All data loaded successfully!")
# Out:
# Loading datasets...
# ✅ All data loaded successfully!

# %%
# Merging Data

# 1. Aggregate total VLE clicks for each student
# We group by student ID, module, and presentation, then sum all click counts
student_clicks = student_vle.groupby(['id_student', 'code_module', 'code_presentation'])['sum_click'].sum().reset_index()

# 2. Merge student demographic data with aggregated click activity
# A left join is used to keep all students even if some have no recorded clicks
df_integrated = pd.merge(student_info, student_clicks, on=['id_student', 'code_module', 'code_presentation'], how='left')

# 3. Replace missing click values with 0
# If a student has no VLE activity record, we treat it as zero clicks
df_integrated['sum_click'] = df_integrated['sum_click'].fillna(0)

# Print confirmation and preview the merged dataset
print("✅ Data merged successfully into 'df_integrated'!")
display(df_integrated.head(3))
# Out:
# ✅ Data merged successfully into 'df_integrated'!
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
#
#    studied_credits disability final_result  sum_click
# 0              240          N         Pass      934.0
# 1               60          N         Pass     1435.0
# 2               60          Y    Withdrawn      281.0

# %%
print(df_integrated.columns.tolist())
# Out:
# ['code_module', 'code_presentation', 'id_student', 'gender', 'region', 'highest_education', 'imd_band', 'age_band', 'num_of_prev_attempts', 'studied_credits', 'disability', 'final_result', 'GDP_per_capita', 'total_early_clicks']

# %%
# --- Visual Analysis After Feature Construction ---

import matplotlib.pyplot as plt
import seaborn as sns

# 1) Distribution of total early clicks
plt.figure(figsize=(8, 4))
sns.histplot(df_integrated['total_early_clicks'], bins=30, kde=True)
plt.title('Distribution of Total Early Clicks')
plt.xlabel('total_early_clicks')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# 2) Students with and without early activity
click_status = df_integrated['total_early_clicks'].gt(0).map({
    True: 'Has Early Clicks',
    False: 'No Early Clicks'
}).value_counts()

plt.figure(figsize=(6, 4))
sns.barplot(x=click_status.index, y=click_status.values)
plt.title('Students With and Without Early VLE Activity')
plt.xlabel('Activity Status')
plt.ylabel('Number of Students')
plt.tight_layout()
plt.show()

# %%
print("=== Insights After Feature Construction ===")
print("- The new feature 'total_early_clicks' was successfully created and added to the integrated dataset.")
print("- Most students have relatively low early interaction levels, while a smaller group shows much higher early activity.")
print("- The distribution of 'total_early_clicks' is right-skewed, indicating the presence of extreme values.")
print("- Some students have no early recorded activity, which may reflect low engagement before the assessment period.")
print("- This feature is useful for later preprocessing and predictive modeling because it captures early behavioral patterns.")
# Out:
# === Insights After Feature Construction ===
# - The new feature 'total_early_clicks' was successfully created and added to the integrated dataset.
# - Most students have relatively low early interaction levels, while a smaller group shows much higher early activity.
# - The distribution of 'total_early_clicks' is right-skewed, indicating the presence of extreme values.
# - Some students have no early recorded activity, which may reflect low engagement before the assessment period.
# - This feature is useful for later preprocessing and predictive modeling because it captures early behavioral patterns.

# %% [markdown]
# ---
# ### Task 1: Select Data
#
# Decide on the data to be used for analysis. Consider which columns (features) and rows (records) to include or exclude based on:
#
# - **Relevance:** Does this feature contribute to the data mining goal?
# - **Data Quality:** Is the quality of this feature sufficient (e.g., too many missing values)?
# - **Technical Constraints:** Are there limitations on data volume or specific feature types?
#
# **Output:** A rationale for inclusion/exclusion of data, and the resulting subset.
#
# **Instructions:** Select the columns and rows relevant to your analysis goal. Document your reasoning.

# %%
columns_to_drop = ['week_from', 'week_to']
vle_mapping = vle_mapping.drop(columns=columns_to_drop)

print("Dropped 'week_from' and 'week_to' from vle_mapping.")
# Out:
# Dropped 'week_from' and 'week_to' from vle_mapping.

# %%
initial_count = len(student_info)
student_info = student_info[student_info['final_result'].notna()]
final_count = len(student_info)

print(f"✅ Filtered student_info: Removed {initial_count - final_count} rows with missing results.")
print(f"📊 Final shape after row selection: {student_info.shape}")
# Out:
# ✅ Filtered student_info: Removed 0 rows with missing results.
# 📊 Final shape after row selection: (32593, 12)

# %% [markdown]
# ---
# ### Task 2: Clean Data
#
# Raise data quality to the level required by the selected analysis techniques. Cleaning activities include:
#
# - **Handle Missing Values:** Impute missing values (mean, median, mode, forward/backward fill) or remove rows/columns with excessive missing data.
# - **Correct Errors:** Fix inaccurate or corrupted data entries.
# - **Remove Duplicates:** Eliminate exact or near-duplicate records.
# - **Handle Outliers:** Decide how to treat extreme values (keep, cap, transform, or remove).
#
# **Instructions:** Apply appropriate cleaning techniques to address the data quality issues identified in Phase 2, Task 4.

# %%
# --- Task 2: Data Cleaning (Handling Missing Values & Outliers) ---

# 1. Fill missing values in the categorical column 'imd_band' using the mode
# The mode represents the most frequent category in the column
df_integrated['imd_band'] = df_integrated['imd_band'].fillna(df_integrated['imd_band'].mode()[0])

# 2. Fill missing click values with 0
# If a student has no recorded VLE activity, we interpret it as zero clicks
df_integrated['sum_click'] = df_integrated['sum_click'].fillna(0)

# 3. Remove duplicate rows from the integrated dataset
# This ensures that each record appears only once after merging and cleaning
df_integrated = df_integrated.drop_duplicates()

# Print confirmation message after completing all cleaning steps
print("✅ Task 2 Done: All cleaning (imputation, duplicates, and nulls) handled in one place.")
# Out:
# ✅ Task 2 Done: All cleaning (imputation, duplicates, and nulls) handled in one place.

# %% [markdown]
# ---
# ### Task 3: Construct Data (Feature Engineering)
#
# This task involves creating new attributes (features) derived from existing ones that may be more useful for modelling. Common techniques include:
#
# - **Derived Attributes:** Create new features from existing ones (e.g., extracting `year`, `month`, `day` from a datetime column; computing `total_spend = price * quantity`).
# - **Binning / Discretisation:** Convert continuous variables into categorical bins (e.g., age groups).
# - **Encoding Categorical Variables:** Convert categorical features into numerical representations (e.g., one-hot encoding, label encoding).
# - **Scaling / Normalisation:** Scale numerical features to a common range (e.g., Min-Max scaling, Standardisation).
#
# **Instructions:** Create new features or transform existing ones to improve model performance.

# %%
early_clicks = student_vle[student_vle['date'] <= 28]


click_summary = early_clicks.groupby(['id_student', 'code_module', 'code_presentation'])['sum_click'].sum().reset_index()
click_summary.rename(columns={'sum_click': 'total_early_clicks'}, inplace=True)

# %%
from sklearn.preprocessing import RobustScaler

# 1. Merge the newly constructed feature into the integrated dataset
# This adds the total early click activity for each student
df_integrated = pd.merge(
    df_integrated,
    click_summary,
    on=['id_student', 'code_module', 'code_presentation'],
    how='left'
)

# Fill missing values in the new feature with 0
# If no early activity is recorded, it is treated as zero early clicks
df_integrated['total_early_clicks'] = df_integrated['total_early_clicks'].fillna(0)

# 2. Scale the early click feature using RobustScaler
# RobustScaler is used because it is less sensitive to outliers
# This is appropriate since outliers were already detected in Phase 2
scaler = RobustScaler()
df_integrated['early_clicks_scaled'] = scaler.fit_transform(df_integrated[['total_early_clicks']])

# 3. Create a binned version of studied_credits
# This groups students into light, medium, and heavy credit load categories
df_integrated['credit_load'] = pd.cut(
    df_integrated['studied_credits'],
    bins=[0, 60, 120, 1000],
    labels=['Light', 'Medium', 'Heavy']
)

# 4. Encode selected categorical variables into numeric format
# This converts text-based categories into dummy variables for modeling
categorical_cols = ['gender', 'age_band', 'highest_education', 'credit_load']
df_final = pd.get_dummies(df_integrated, columns=categorical_cols, drop_first=True)

# Print confirmation and preview the final prepared dataset
print("✅ Task 3 Complete: Features constructed, scaled, and encoded!")
display(df_final.head(3))
# Out:
# ✅ Task 3 Complete: Features constructed, scaled, and encoded!
#   code_module code_presentation  id_student                region imd_band  \
# 0         AAA             2013J       11391   East Anglian Region  90-100%
# 1         AAA             2013J       28400              Scotland   20-30%
# 2         AAA             2013J       30268  North Western Region   30-40%
#
#    num_of_prev_attempts  studied_credits disability final_result  sum_click  \
# 0                     0              240          N         Pass      934.0
# 1                     0               60          N         Pass     1435.0
# 2                     0               60          Y    Withdrawn      281.0
#
#    total_early_clicks  early_clicks_scaled  gender_M  age_band_35-55  \
# 0               400.0             0.648725      True           False
# 1               609.0             1.240793     False            True
# 2               260.0             0.252125     False            True
#
#    age_band_55<=  highest_education_HE Qualification  \
# 0           True                                True
# 1          False                                True
# 2          False                               False
#
#    highest_education_Lower Than A Level  highest_education_No Formal quals  \
# 0                                 False                              False
# 1                                 False                              False
# 2                                 False                              False
#
#    highest_education_Post Graduate Qualification  credit_load_Medium  \
# 0                                          False               False
# 1                                          False               False
# 2                                          False               False
#
#    credit_load_Heavy
# 0               True
# 1              False
# 2              False

# %%
print(f"Aggregated clickstream data into {len(click_summary):,} student summaries.")
display(click_summary.head())
# Out:
# Aggregated clickstream data into 28,792 student summaries.
#    id_student code_module code_presentation  total_early_clicks
# 0        6516         AAA             2014J                 812
# 1        8462         DDD             2013J                 369
# 2        8462         DDD             2014J                   9
# 3       11391         AAA             2013J                 400
# 4       23629         BBB             2013B                  51

# %%
# --- Phase 3: IQR Verification for New Numerical Features ---

numerical_features_phase3 = ['total_early_clicks', 'GDP_per_capita']

print("=== Phase 3: IQR Verification for New Numerical Features ===\n")

iqr_results_phase3 = {}

for col in numerical_features_phase3:
    Q1 = df_final[col].quantile(0.25)
    Q3 = df_final[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df_final[(df_final[col] < lower_bound) | (df_final[col] > upper_bound)]
    outliers_count = len(outliers)

    iqr_results_phase3[col] = outliers_count

    print(f"Column: {col}")
    print(f"Normal Range: [{lower_bound:.2f}, {upper_bound:.2f}]")
    print(f"Outliers Count: {outliers_count}")
    print("-" * 50)
# Out:
# === Phase 3: IQR Verification for New Numerical Features ===
#
# Column: total_early_clicks
# Normal Range: [-484.50, 927.50]
# Outliers Count: 2006
# --------------------------------------------------
# Column: GDP_per_capita
# Normal Range: [29325.39, 29325.39]
# Outliers Count: 3766
# --------------------------------------------------

# %%
print("=== Phase 3 Outlier Summary ===")
for col, count in iqr_results_phase3.items():
    print(f"{col}: {count} outliers detected")
# Out:
# === Phase 3 Outlier Summary ===
# total_early_clicks: 2006 outliers detected
# GDP_per_capita: 3766 outliers detected

# %% [markdown]
# ---
# ### Task 4: Integrate Data
#
# If your project uses multiple data sources, this task involves merging or combining them into a single, unified dataset. Activities include:
#
# - **Merging Tables:** Join datasets on common keys (e.g., using `pd.merge()`).
# - **Appending Records:** Concatenate datasets with the same structure (e.g., using `pd.concat()`).
# - **Aggregation:** Summarise data at a different level of granularity.
#
# **Instructions:** If using multiple data sources, merge or concatenate them below. If your project uses a single dataset, document that here and proceed to the next task.

# %%
# %pip install requests beautifulsoup4 lxml
# %pip install html5lib
# Out:
# Requirement already satisfied: requests in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (2.33.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (4.14.3)
# Requirement already satisfied: lxml in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (6.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (from requests) (2026.2.25)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: html5lib in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\mohamed el gaby\.conda\envs\kh5004\lib\site-packages (from html5lib) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import io

print("=== 1. Starting Web Scraping (BeautifulSoup) ===")
url = 'https://en.wikipedia.org/wiki/List_of_regions_of_the_United_Kingdom_by_GRP_per_capita'


headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}
response = requests.get(url, headers=headers)


soup = BeautifulSoup(response.text, 'html.parser')


scraped_df = pd.read_html(io.StringIO(str(soup)), match='Region')[0]


scraped_df = scraped_df.iloc[:, [0, 2]]
scraped_df.columns = ['Region_Name', 'GDP_per_capita']


region_mapping = {
    'Scotland': 'Scotland',
    'Wales': 'Wales',
    'London': 'London Region',
    'South East England': 'South East Region',
    'South West England': 'South West Region',
    'East of England': 'East Anglian Region',
    'East Midlands': 'East Midlands Region',
    'West Midlands': 'West Midlands Region',
    'Yorkshire and the Humber': 'Yorkshire Region',
    'North West England': 'North Western Region',
    'North East England': 'North Region',
    'Northern Ireland': 'Ireland'
}


scraped_df['region'] = scraped_df['Region_Name'].map(region_mapping)
scraped_df = scraped_df.dropna(subset=['region'])
print(f"✅ Successfully scraped and cleaned {len(scraped_df)} regional records.")

print("\n=== 2. Integrating Data ===")

df_integrated = pd.merge(student_info, scraped_df[['region', 'GDP_per_capita']], on='region', how='left')


df_integrated = pd.merge(df_integrated, click_summary, on=['id_student', 'code_module', 'code_presentation'], how='left')


df_integrated['total_early_clicks'] = df_integrated['total_early_clicks'].fillna(0)


df_integrated['GDP_per_capita'] = df_integrated['GDP_per_capita'].fillna(df_integrated['GDP_per_capita'].mode()[0])

print(f"✅ Integration complete! Final shape: {df_integrated.shape}")
# Out:
# === 1. Starting Web Scraping (BeautifulSoup) ===
# ✅ Successfully scraped and cleaned 2 regional records.
#
# === 2. Integrating Data ===
# ✅ Integration complete! Final shape: (32593, 14)

# %%
# --- Task 4: Integrating Web-Scraped Data & Final Merge ---

# 1. Clean the GDP column before merging
# Convert the column to string first, remove currency symbols and commas,
# replace invalid 'nan' text with '0', then convert the result to float
scraped_df['GDP_per_capita'] = (
    scraped_df['GDP_per_capita']
    .astype(str)
    .str.replace('€', '', regex=False)
    .str.replace(',', '', regex=False)
    .replace('nan', '0')
    .astype(float)
)

# 2. Merge GDP data with student information using the region column
# A left join is used so that all student records are preserved
df_final = pd.merge(student_info, scraped_df[['region', 'GDP_per_capita']], on='region', how='left')

# 3. Merge the early click summary feature into the final dataset
# This adds the total early click activity for each student
df_final = pd.merge(df_final, click_summary, on=['id_student', 'code_module', 'code_presentation'], how='left')

# 4. Handle missing values after merging
# Missing early click values are treated as zero activity
df_final['total_early_clicks'] = df_final['total_early_clicks'].fillna(0)

# Replace zero or missing GDP values with the mean GDP value
# This ensures that the GDP feature has no missing or invalid values
df_final['GDP_per_capita'] = df_final['GDP_per_capita'].replace(0, df_final['GDP_per_capita'].mean())
df_final['GDP_per_capita'] = df_final['GDP_per_capita'].fillna(df_final['GDP_per_capita'].mean())

# Print confirmation message and preview the final merged dataset
print("✅ Integration complete! Web-scraped data (GDP) and early clicks merged.")
print(f"Final Dataset Shape: {df_final.shape}")
display(df_final.head(3))
# Out:
# ✅ Integration complete! Web-scraped data (GDP) and early clicks merged.
# Final Dataset Shape: (32593, 14)
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
#
#    studied_credits disability final_result  GDP_per_capita  total_early_clicks
# 0              240          N         Pass    29325.385024               400.0
# 1               60          N         Pass    29325.385024               609.0
# 2               60          Y    Withdrawn    29325.385024               260.0

# %% [markdown]
# ---
# ### Task 5: Format Data
#
# This final preparation task ensures the data is in the correct format for the modelling tools. Activities include:
#
# - **Data Type Conversions:** Ensure all columns have appropriate data types (e.g., numeric, datetime, categorical).
# - **Column Reordering:** Arrange columns in a logical order (e.g., features first, target last).
# - **Renaming:** Give columns clear, descriptive names.
# - **Saving the Prepared Dataset:** Export the final, clean dataset for use in subsequent phases.
#
# **Instructions:** Apply any final formatting changes and save the prepared dataset.

# %%
# --- Task 5: Final Data Selection & Numerical Encoding ---

# 1. Convert the target variable into binary format
# Students with Pass or Distinction are labeled as 0 (Safe),
# while Fail or Withdrawn are labeled as 1 (At-Risk)
if 'final_result' in df_final.columns:
    target_mapping = {'Pass': 0, 'Distinction': 0, 'Fail': 1, 'Withdrawn': 1}
    df_final['target_risk'] = df_final['final_result'].map(target_mapping)

# 2. Remove columns that are not needed for modeling
# These include identifiers, descriptive fields, and the original target column
cols_to_drop = ['id_student', 'code_module', 'code_presentation', 'region', 'final_result']
df_temp = df_final.drop(columns=cols_to_drop, errors='ignore')

# 3. Fill any remaining missing values
# Categorical columns are filled with the mode,
# while numerical columns are filled with the median
for col in df_temp.columns:
    if df_temp[col].dtype == 'object':
        df_temp[col] = df_temp[col].fillna(df_temp[col].mode()[0])
    else:
        df_temp[col] = df_temp[col].fillna(df_temp[col].median())

# 4. Encode all remaining categorical columns into numeric form
# One-hot encoding is used so the dataset becomes fully ready for modeling
df_prepared = pd.get_dummies(df_temp, drop_first=True)

# 5. Print a final summary of the prepared dataset
print("\n" + "="*40)
print("🚀 PHASE 3 IS OFFICIALLY COMPLETE")
print(f"📊 Final Numerical Shape: {df_prepared.shape}")
print(f"🧹 Remaining Missing Values: {df_prepared.isnull().sum().sum()}")
print("="*40)

# Save the final modeling-ready dataset as a CSV file
df_prepared.to_csv('final_data_ready_for_modeling.csv', index=False)

# Preview the first rows of the final prepared dataset
display(df_prepared.head(3))
# Out:
# ========================================
# 🚀 PHASE 3 IS OFFICIALLY COMPLETE
# 📊 Final Numerical Shape: (32593, 22)
# 🧹 Remaining Missing Values: 0
# ========================================
#    num_of_prev_attempts  studied_credits  GDP_per_capita  total_early_clicks  \
# 0                     0              240    29325.385024               400.0
# 1                     0               60    29325.385024               609.0
# 2                     0               60    29325.385024               260.0
#
#    target_risk  gender_M  highest_education_HE Qualification  \
# 0            0      True                                True
# 1            0     False                                True
# 2            1     False                               False
#
#    highest_education_Lower Than A Level  highest_education_No Formal quals  \
# 0                                 False                              False
# 1                                 False                              False
# 2                                 False                              False
#
#    highest_education_Post Graduate Qualification  imd_band_10-20  \
# 0                                          False           False
# 1                                          False           False
# 2                                          False           False
#
#    imd_band_20-30%  imd_band_30-40%  imd_band_40-50%  imd_band_50-60%  \
# 0            False            False            False            False
# 1             True            False            False            False
# 2            False             True            False            False
#
#    imd_band_60-70%  imd_band_70-80%  imd_band_80-90%  imd_band_90-100%  \
# 0            False            False            False              True
# 1            False            False            False             False
# 2            False            False            False             False
#
#    age_band_35-55  age_band_55<=  disability_Y
# 0           False           True         False
# 1            True          False         False
# 2            True          False          True

# %%
print("=" * 60)
print("FINAL PREPARED DATASET SUMMARY")
print("=" * 60)

print(f"✅ Shape: {df_final.shape}")
print(f"❌ Missing values: {df_final.isnull().sum().sum()}")
print(f"🔄 Duplicates: {df_final.duplicated().sum()}")
print("\n📋 Column types:")
print(df_final.dtypes)


display(df_final.head())
# Out:
# ============================================================
# FINAL PREPARED DATASET SUMMARY
# ============================================================
# ✅ Shape: (32593, 13)
# ❌ Missing values: 0
# 🔄 Duplicates: 232
#
# 📋 Column types:
# code_module              object
# code_presentation        object
# gender                   object
# region                   object
# highest_education        object
# imd_band                 object
# age_band                 object
# num_of_prev_attempts      int64
# studied_credits           int64
# disability               object
# GDP_per_capita          float64
# total_early_clicks      float64
# target_risk               int64
# dtype: object
#   code_module code_presentation gender                region  \
# 0         AAA             2013J      M   East Anglian Region
# 1         AAA             2013J      F              Scotland
# 2         AAA             2013J      F  North Western Region
# 3         AAA             2013J      F     South East Region
# 4         AAA             2013J      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability  GDP_per_capita  total_early_clicks  target_risk
# 0              240          N         30300.0               400.0            0
# 1               60          N         30300.0               609.0            0
# 2               60          Y         30300.0               260.0            1
# 3               60          N         30300.0               469.0            0
# 4               60          N         30300.0               559.0            0

# %%
df_final.to_csv(OUTPUT_PATH, index=False)

print(f"✅ Success! Prepared dataset saved to: {OUTPUT_PATH}")
print("🚀 Ready for Phase 4: Modelling.")
# Out:
# ✅ Success! Prepared dataset saved to: ../data/prepared_student_data.csv
# 🚀 Ready for Phase 4: Modelling.
